# %% [markdown]
# # NMTLR

# %%
import numpy as np
import matplotlib.pyplot as plt

# For preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper 

import torch # For building the networks 
import torchtuples as tt # Some useful functions

#from pycox.datasets import metabric
from pycox.models import MTLR
from pycox.evaluation import EvalSurv
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from pycox.models.utils import pad_col

# %%
def analyze_file(data):
    print("Dataset:")
    display(data)
    
    # Output the shape of the dataset
    print("\nShape of the dataset (rows, columns):")
    print(data.shape)
    
    # Output the data types of each column
    print("\nData types of each column:")
    print(data.dtypes)
    
    # Output the count of missing values in each column
    print("\nCount of missing values in each column:")
    print(data.isnull().sum())
def get_high_correlation_features(df, target_columns, threshold=0.9):
    """
    Get features with correlation greater than the specified threshold with the target variables.

    Parameters:
    - df (pd.DataFrame): The input DataFrame with features and target variables.
    - target_columns (list of str): List of target variable column names.
    - threshold (float): Correlation threshold to filter features.

    Returns:
    - dict: A dictionary where keys are column names and values are their correlation values.
    """
    high_corr_features = {}

    # Compute correlation matrix
    corr_matrix = df.corr()

    # Iterate over columns in the DataFrame
    for column in df.columns:
        if column not in target_columns:
            # Check correlation with each target variable
            for target in target_columns:
                correlation_value = corr_matrix.loc[column, target]
                if abs(correlation_value) > threshold:
                    high_corr_features[column] = correlation_value
                    break  # No need to check other targets for this feature

    return high_corr_features

# %%
np.random.seed(1234)
_ = torch.manual_seed(123)

# %% [markdown]
# # Dataset

# %%
data = pd.read_csv('/Users/simrantanwar/Desktop/College/DDP/survival_analysis/data/genomics_brain_16_09_24.csv')
analyze_file(data)
# Out:
# Dataset:
#      Unnamed: 0    Patient ID     LASP1    HOXA11    CREBBP       ETV1  \
# 0             0  TCGA-02-0047  8.923858  3.526361  8.244071   8.900549
# 1             1  TCGA-02-0055  8.460199  3.970292  7.816014   7.650645
# 2             2  TCGA-02-2483  9.164296  4.682131  8.572628  10.186973
# 3             3  TCGA-02-2485  9.133675  3.970292  8.474077   9.155250
# 4             4  TCGA-02-2486  8.626765  3.526361  7.090910   6.838405
# ..          ...           ...       ...       ...       ...        ...
# 660        8698  TCGA-WY-A85A  9.093245  1.791759  8.631414  10.231928
# 661        8699  TCGA-WY-A85B  8.977778  2.397895  8.905037  10.492523
# 662        8700  TCGA-WY-A85C  8.820552  6.282267  9.278466   9.983315
# 663        8701  TCGA-WY-A85D  8.793612  0.000000  8.634443   8.751316
# 664        8702  TCGA-WY-A85E  9.264734  6.905753  9.007490  11.213805
#
#          GAS7     CD79B      PAX7       BTK  ...      CUX1   PIERCE2  \
# 0    9.184510  3.555348  2.302585  6.255750  ...  8.282483  4.127134
# 1    7.964156  2.890372  1.609438  6.614726  ...  8.368693  4.276666
# 2    8.340217  2.944439  1.609438  6.146329  ...  8.606302  3.931826
# 3    6.938284  2.564949  1.791759  5.780744  ...  8.629629  4.369448
# 4    8.690642  2.995732  0.693147  7.329750  ...  8.512382  5.793014
# ..        ...       ...       ...       ...  ...       ...       ...
# 660  7.642524  0.693147  2.397895  5.602119  ...  8.810460  3.891820
# 661  7.574558  2.484907  1.386294  6.572283  ...  9.015906  4.234107
# 662  7.007601  1.945910  1.945910  5.730100  ...  9.177714  3.610918
# 663  7.677400  2.197225  0.000000  5.983936  ...  8.861208  3.637586
# 664  8.427925  1.098612  3.178054  5.575949  ...  9.214631  3.828641
#
#        SRGAP2     NCOA4  SSX4     TAF15     MLLT6  DUX4L1   OS  OS.time
# 0    8.053251  9.012621   0.0  8.319474  8.334952     0.0  1.0    448.0
# 1    7.794823  8.727130   0.0  8.235361  7.855157     0.0  1.0     76.0
# 2    8.222554  9.270965   0.0  8.883779  8.491260     0.0  0.0    466.0
# 3    8.235361  8.687779   0.0  9.019301  8.461046     0.0  0.0    470.0
# 4    7.963460  8.760139   0.0  8.525161  8.006034     0.0  1.0    618.0
# ..        ...       ...   ...       ...       ...     ...  ...      ...
# 660  7.765993  8.910586   0.0  8.927977  9.006509     0.0  0.0   1320.0
# 661  7.955074  9.328568   0.0  9.316770  9.229849     0.0  0.0   1393.0
# 662  8.107720  9.145909   0.0  9.151757  9.219696     0.0  0.0   1426.0
# 663  7.914983  8.731498   0.0  9.364005  8.856234     0.0  0.0   1147.0
# 664  8.082402  9.217812   0.0  9.259511  9.265018     0.0  0.0    633.0
#
# [665 rows x 752 columns]
# Shape of the dataset (rows, columns):
# (665, 752)
#
# Data types of each column:
# Unnamed: 0      int64
# Patient ID     object
# LASP1         float64
# HOXA11        float64
# CREBBP        float64
#                ...
# TAF15         float64
# MLLT6         float64
# DUX4L1        float64
# OS            float64
# OS.time       float64
# Length: 752, dtype: object
#
# Count of missing values in each column:
# Unnamed: 0    0
# Patient ID    0
# LASP1         0
# HOXA11        0
# CREBBP        0
#              ..
# TAF15         0
# MLLT6         0
# DUX4L1        0
# OS            0
# OS.time       0
# Length: 752, dtype: int64

# %%
df = data.drop(columns=['Unnamed: 0','Patient ID'], axis=1)
analyze_file(df)
# Out:
# Dataset:
#         LASP1    HOXA11    CREBBP       ETV1      GAS7     CD79B      PAX7  \
# 0    8.923858  3.526361  8.244071   8.900549  9.184510  3.555348  2.302585
# 1    8.460199  3.970292  7.816014   7.650645  7.964156  2.890372  1.609438
# 2    9.164296  4.682131  8.572628  10.186973  8.340217  2.944439  1.609438
# 3    9.133675  3.970292  8.474077   9.155250  6.938284  2.564949  1.791759
# 4    8.626765  3.526361  7.090910   6.838405  8.690642  2.995732  0.693147
# ..        ...       ...       ...        ...       ...       ...       ...
# 660  9.093245  1.791759  8.631414  10.231928  7.642524  0.693147  2.397895
# 661  8.977778  2.397895  8.905037  10.492523  7.574558  2.484907  1.386294
# 662  8.820552  6.282267  9.278466   9.983315  7.007601  1.945910  1.945910
# 663  8.793612  0.000000  8.634443   8.751316  7.677400  2.197225  0.000000
# 664  9.264734  6.905753  9.007490  11.213805  8.427925  1.098612  3.178054
#
#           BTK     BRCA1       WAS  ...      CUX1   PIERCE2    SRGAP2  \
# 0    6.255750  6.257668  7.026427  ...  8.282483  4.127134  8.053251
# 1    6.614726  5.605802  7.315884  ...  8.368693  4.276666  7.794823
# 2    6.146329  6.932448  6.867974  ...  8.606302  3.931826  8.222554
# 3    5.780744  6.970730  6.242223  ...  8.629629  4.369448  8.235361
# 4    7.329750  5.683580  7.600902  ...  8.512382  5.793014  7.963460
# ..        ...       ...       ...  ...       ...       ...       ...
# 660  5.602119  5.849325  6.272877  ...  8.810460  3.891820  7.765993
# 661  6.572283  6.376727  7.059618  ...  9.015906  4.234107  7.955074
# 662  5.730100  6.347389  6.428105  ...  9.177714  3.610918  8.107720
# 663  5.983936  5.796058  6.858565  ...  8.861208  3.637586  7.914983
# 664  5.575949  6.218600  6.347389  ...  9.214631  3.828641  8.082402
#
#         NCOA4  SSX4     TAF15     MLLT6  DUX4L1   OS  OS.time
# 0    9.012621   0.0  8.319474  8.334952     0.0  1.0    448.0
# 1    8.727130   0.0  8.235361  7.855157     0.0  1.0     76.0
# 2    9.270965   0.0  8.883779  8.491260     0.0  0.0    466.0
# 3    8.687779   0.0  9.019301  8.461046     0.0  0.0    470.0
# 4    8.760139   0.0  8.525161  8.006034     0.0  1.0    618.0
# ..        ...   ...       ...       ...     ...  ...      ...
# 660  8.910586   0.0  8.927977  9.006509     0.0  0.0   1320.0
# 661  9.328568   0.0  9.316770  9.229849     0.0  0.0   1393.0
# 662  9.145909   0.0  9.151757  9.219696     0.0  0.0   1426.0
# 663  8.731498   0.0  9.364005  8.856234     0.0  0.0   1147.0
# 664  9.217812   0.0  9.259511  9.265018     0.0  0.0    633.0
#
# [665 rows x 750 columns]
# Shape of the dataset (rows, columns):
# (665, 750)
#
# Data types of each column:
# LASP1      float64
# HOXA11     float64
# CREBBP     float64
# ETV1       float64
# GAS7       float64
#             ...
# TAF15      float64
# MLLT6      float64
# DUX4L1     float64
# OS         float64
# OS.time    float64
# Length: 750, dtype: object
#
# Count of missing values in each column:
# LASP1      0
# HOXA11     0
# CREBBP     0
# ETV1       0
# GAS7       0
#           ..
# TAF15      0
# MLLT6      0
# DUX4L1     0
# OS         0
# OS.time    0
# Length: 750, dtype: int64

# %%
target_columns = ['OS','OS.time']
corr_value = get_high_correlation_features(df, target_columns, threshold=0.3)
#print(corr_value)
print(len(corr_value))
sorted_corr_value = dict(sorted(corr_value.items(), key=lambda item: item[1], reverse=True))
# Out:
# 131

# %% [markdown]
# # Top 10 corr

# %%
top_20_genes =list(sorted_corr_value.keys())[:20]
print(top_20_genes)

# Assuming 'target' and 'duration' are already identified from the column names
target_columns = ['OS','OS.time']

# Combine the top 20 genes and the additional columns
columns_to_select =  top_20_genes + target_columns

# Create a new DataFrame with these columns
top_20_genes_df = df[columns_to_select]
# Out:
# ['HOXD11', 'MSN', 'IGF2BP2', 'TMSB4X', 'HOXC11', 'FKBP9', 'HOXC13', 'HOXD13', 'HMGA2', 'CDKN2C', 'STIL', 'MACC1', 'PAX3', 'CHEK2', 'SOCS1', 'BCL2L12', 'COL3A1', 'LATS2', 'TPM4', 'ASPM']

# %%
# Create a test set by sampling 20% of the training data
df_test = top_20_genes_df.sample(frac=0.2)

# Remove the test set from the original training data
df_train = top_20_genes_df.drop(df_test.index)

# Create a validation set by sampling 20% of the remaining training data
df_val = df_train.sample(frac=0.2)

# Remove the validation set from the remaining training data
df_train = df_train.drop(df_val.index)

# %%
analyze_file(df_train)
# Out:
# Dataset:
#        HOXD11        MSN   IGF2BP2     TMSB4X    HOXC11     FKBP9    HOXC13  \
# 0    3.871201  10.236884  6.167516  11.127586  4.276666  8.697012  2.833213
# 1    3.496508  10.350606  6.946976  11.797405  4.430817  9.072227  4.644391
# 2    2.079442   9.214233  6.539586  11.569457  5.855072  7.635304  5.420535
# 3    4.770685   9.937454  5.278115  11.443211  6.523562  8.772145  6.982863
# 4    2.397895  10.488855  7.297091  12.058431  1.791759  8.614138  1.945910
# ..        ...        ...       ...        ...       ...       ...       ...
# 658  0.000000   9.066470  3.912023  10.912285  0.000000  7.338888  0.000000
# 659  0.000000   7.939872  4.060443  10.650010  1.791759  7.598900  0.000000
# 660  0.000000   9.538708  3.367296   9.935858  0.000000  7.261225  0.000000
# 661  0.000000   8.551208  3.178054  10.644877  0.000000  7.042286  0.000000
# 663  0.000000   7.981733  2.772589  10.751585  0.000000  6.658011  0.000000
#
#        HOXD13     HMGA2    CDKN2C  ...      PAX3     CHEK2     SOCS1  \
# 0    5.703782  4.174387  7.558517  ...  1.609438  5.627621  3.951244
# 1    5.075174  6.177944  7.784889  ...  4.564348  6.519147  5.707110
# 2    6.206576  4.394449  8.771990  ...  2.484907  6.917706  4.343805
# 3    6.860664  3.806662  8.491875  ...  4.709530  6.302619  5.480639
# 4    2.484907  6.018593  7.006695  ...  3.555348  5.176150  5.247024
# ..        ...       ...       ...  ...       ...       ...       ...
# 658  0.000000  1.098612  7.400621  ...  0.000000  5.278115  3.258097
# 659  3.465736  0.693147  6.403574  ...  1.609438  5.236442  4.219508
# 660  0.000000  0.000000  5.505332  ...  0.000000  4.465908  3.688879
# 661  0.000000  0.000000  7.191429  ...  0.693147  5.811141  3.401197
# 663  0.000000  0.000000  6.104793  ...  0.000000  4.753590  3.218876
#
#       BCL2L12     COL3A1     LATS2       TPM4      ASPM   OS  OS.time
# 0    5.323010   9.246286  6.897705   9.437317  6.190315  1.0    448.0
# 1    6.522093  12.306782  7.538495  11.129731  6.148468  1.0     76.0
# 2    5.805135   9.506214  6.061457  10.279593  7.674617  0.0    466.0
# 3    6.421622   8.315322  6.984716   9.955606  6.776507  0.0    470.0
# 4    6.131226   8.352083  6.476972   9.976180  4.234107  1.0    618.0
# ..        ...        ...       ...        ...       ...  ...      ...
# 658  5.323010   7.425358  5.966147   8.826001  4.997212  0.0   1337.0
# 659  5.398163   4.543295  4.955827   8.721765  4.912655  0.0   1213.0
# 660  4.564348   5.010635  5.081404   8.266935  3.988984  0.0   1320.0
# 661  5.327876   6.208590  4.663439   8.597851  6.313548  0.0   1393.0
# 663  5.241747   4.094345  4.330733   8.133294  3.258097  0.0   1147.0
#
# [426 rows x 22 columns]
# Shape of the dataset (rows, columns):
# (426, 22)
#
# Data types of each column:
# HOXD11     float64
# MSN        float64
# IGF2BP2    float64
# TMSB4X     float64
# HOXC11     float64
# FKBP9      float64
# HOXC13     float64
# HOXD13     float64
# HMGA2      float64
# CDKN2C     float64
# STIL       float64
# MACC1      float64
# PAX3       float64
# CHEK2      float64
# SOCS1      float64
# BCL2L12    float64
# COL3A1     float64
# LATS2      float64
# TPM4       float64
# ASPM       float64
# OS         float64
# OS.time    float64
# dtype: object
#
# Count of missing values in each column:
# HOXD11     0
# MSN        0
# IGF2BP2    0
# TMSB4X     0
# HOXC11     0
# FKBP9      0
# HOXC13     0
# HOXD13     0
# HMGA2      0
# CDKN2C     0
# STIL       0
# MACC1      0
# PAX3       0
# CHEK2      0
# SOCS1      0
# BCL2L12    0
# COL3A1     0
# LATS2      0
# TPM4       0
# ASPM       0
# OS         0
# OS.time    0
# dtype: int64
# ERROR! Session/line number was not unique in database. History logging moved to new session 8

# %% [markdown]
# # Featrue transform

# %%
columns = top_20_genes_df.columns.tolist()
cols_standardize = columns[:-2]+columns[-1:]
print(cols_standardize)
#cols_leave = ['type', 'gender','Outcome','tumor_status','OS']

standardize = [([col], StandardScaler()) for col in cols_standardize]
#leave = [(col, None) for col in cols_leave]

x_mapper = DataFrameMapper(standardize)
# Out:
# ['HOXD11', 'MSN', 'IGF2BP2', 'TMSB4X', 'HOXC11', 'FKBP9', 'HOXC13', 'HOXD13', 'HMGA2', 'CDKN2C', 'STIL', 'MACC1', 'PAX3', 'CHEK2', 'SOCS1', 'BCL2L12', 'COL3A1', 'LATS2', 'TPM4', 'ASPM', 'OS.time']

# %%
x_train = x_mapper.fit_transform(df_train).astype('float32')
x_val = x_mapper.transform(df_val).astype('float32')
x_test = x_mapper.transform(df_test).astype('float32')

# %% [markdown]
# # Label Transforms
# The survival methods require individual label transforms, so we have included a proposed label_transform for each method. In this case label_transform is just a shorthand for the class pycox.preprocessing.label_transforms.LabTransDiscreteTime.
#
# The MTLR is a discrete-time method, meaning it requires discretization of the event times to be applied to continuous-time data. We let num_durations define the size of this (equidistant) discretization grid, meaning our network will have num_durations output nodes.

# %%
num_durations = 10
labtrans = MTLR.label_transform(num_durations)
get_target = lambda gene_expressions_10_df: (gene_expressions_10_df['OS.time'].values, gene_expressions_10_df['OS'].values)
y_train = labtrans.fit_transform(*get_target(df_train))
y_val = labtrans.transform(*get_target(df_val))

train = (x_train, y_train)
val = (x_val, y_val)

# We don't need to transform the test labels
durations_test, events_test = get_target(df_test)

# %%
type(labtrans)
# Out:
# pycox.preprocessing.label_transforms.LabTransDiscreteTime

# %% [markdown]
# # Neural Net
# We make a neural net with torch. For simple network structures, we can use the MLPVanilla provided by torchtuples.\
# The following net is an MLP with two hidden layers (with 32 nodes each), ReLU activations, and num_nodes output nodes. We also have batch normalization and dropout between the layers.

# %%
in_features = x_train.shape[1]
num_nodes = [32, 32]
out_features = labtrans.out_features
batch_norm = True
dropout = 0.4

net = tt.practical.MLPVanilla(in_features, num_nodes, out_features, batch_norm, dropout)

# %% [markdown]
# # Training

# %%
model = MTLR(net, tt.optim.Adam, duration_index=labtrans.cuts)

# %%
batch_size = 32
lr_finder = model.lr_finder(x_train, y_train, batch_size, tolerance=6)
_ = lr_finder.plot()
# Out:
# /Users/simrantanwar/opt/anaconda3/envs/venv/lib/python3.9/site-packages/torchtuples/base.py:669: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.net.load_state_dict(torch.load(path, **kwargs))

# %%
lr_finder.get_best_lr()
# Out:
# np.float64(0.0001)

# %%
model.optimizer.set_lr(0.0001)

# %%
epochs = 75
callbacks = [tt.callbacks.EarlyStopping()]
log = model.fit(x_train, y_train, batch_size, epochs, callbacks, val_data=val)
# Out:
# 0:	[0s / 0s],		train_loss: 1.2436,	val_loss: 0.9295
# 1:	[0s / 0s],		train_loss: 1.2193,	val_loss: 0.9757
# 2:	[0s / 0s],		train_loss: 1.2523,	val_loss: 0.9708
# 3:	[0s / 0s],		train_loss: 1.1559,	val_loss: 0.9521
# 4:	[0s / 0s],		train_loss: 1.1204,	val_loss: 0.9242
# 5:	[0s / 0s],		train_loss: 1.0893,	val_loss: 0.9102
# 6:	[0s / 0s],		train_loss: 1.1334,	val_loss: 0.8800
# 7:	[0s / 0s],		train_loss: 1.0259,	val_loss: 0.8786
# 8:	[0s / 0s],		train_loss: 1.0549,	val_loss: 0.8743
# 9:	[0s / 0s],		train_loss: 1.0245,	val_loss: 0.8734
# 10:	[0s / 0s],		train_loss: 0.9985,	val_loss: 0.8488
# 11:	[0s / 0s],		train_loss: 1.0087,	val_loss: 0.8518
# 12:	[0s / 0s],		train_loss: 0.9888,	val_loss: 0.8269
# 13:	[0s / 0s],		train_loss: 1.0090,	val_loss: 0.8212
# 14:	[0s / 0s],		train_loss: 0.9381,	val_loss: 0.8034
# 15:	[0s / 0s],		train_loss: 0.9995,	val_loss: 0.8082
# 16:	[0s / 0s],		train_loss: 0.9596,	val_loss: 0.8191
# 17:	[0s / 0s],		train_loss: 0.9436,	val_loss: 0.7985
# 18:	[0s / 0s],		train_loss: 0.9046,	val_loss: 0.8006
# 19:	[0s / 0s],		train_loss: 0.8485,	val_loss: 0.7866
# 20:	[0s / 0s],		train_loss: 0.9099,	val_loss: 0.7786
# 21:	[0s / 0s],		train_loss: 0.8865,	val_loss: 0.7772
# 22:	[0s / 0s],		train_loss: 0.8774,	val_loss: 0.7756
# 23:	[0s / 0s],		train_loss: 0.9479,	val_loss: 0.7995
# 24:	[0s / 0s],		train_loss: 0.8166,	val_loss: 0.7525
# 25:	[0s / 0s],		train_loss: 0.8713,	val_loss: 0.7497
# 26:	[0s / 0s],		train_loss: 0.8408,	val_loss: 0.7482
# 27:	[0s / 0s],		train_loss: 0.8091,	val_loss: 0.7313
# 28:	[0s / 0s],		train_loss: 0.8627,	val_loss: 0.7350
# 29:	[0s / 0s],		train_loss: 0.8297,	val_loss: 0.7271
# 30:	[0s / 0s],		train_loss: 0.8165,	val_loss: 0.7267
# 31:	[0s / 0s],		train_loss: 0.7453,	val_loss: 0.7047
# 32:	[0s / 0s],		train_loss: 0.8368,	val_loss: 0.7157
# 33:	[0s / 0s],		train_loss: 0.8000,	val_loss: 0.7335
# 34:	[0s / 0s],		train_loss: 0.7469,	val_loss: 0.7022
# 35:	[0s / 0s],		train_loss: 0.7880,	val_loss: 0.7066
# 36:	[0s / 0s],		train_loss: 0.7783,	val_loss: 0.7086
# 37:	[0s / 0s],		train_loss: 0.7217,	val_loss: 0.7092
# 38:	[0s / 0s],		train_loss: 0.8017,	val_loss: 0.6958
# 39:	[0s / 0s],		train_loss: 0.7282,	val_loss: 0.6856
# 40:	[0s / 0s],		train_loss: 0.7623,	val_loss: 0.6914
# 41:	[0s / 0s],		train_loss: 0.7247,	val_loss: 0.6763
# 42:	[0s / 0s],		train_loss: 0.7191,	val_loss: 0.6798
# 43:	[0s / 0s],		train_loss: 0.7549,	val_loss: 0.6583
# 44:	[0s / 0s],		train_loss: 0.6997,	val_loss: 0.6759
# 45:	[0s / 0s],		train_loss: 0.6976,	val_loss: 0.6701
# 46:	[0s / 0s],		train_loss: 0.7736,	val_loss: 0.6713
# 47:	[0s / 0s],		train_loss: 0.7872,	val_loss: 0.6500
# 48:	[0s / 0s],		train_loss: 0.6898,	val_loss: 0.6550
# 49:	[0s / 0s],		train_loss: 0.7322,	val_loss: 0.6477
# 50:	[0s / 0s],		train_loss: 0.6713,	val_loss: 0.6520
# 51:	[0s / 0s],		train_loss: 0.6744,	val_loss: 0.6659
# 52:	[0s / 0s],		train_loss: 0.7164,	val_loss: 0.6605
# 53:	[0s / 0s],		train_loss: 0.6863,	val_loss: 0.6620
# 54:	[0s / 0s],		train_loss: 0.6608,	val_loss: 0.6722
# 55:	[0s / 0s],		train_loss: 0.6916,	val_loss: 0.6551
# 56:	[0s / 0s],		train_loss: 0.7006,	val_loss: 0.6533
# 57:	[0s / 0s],		train_loss: 0.7115,	val_loss: 0.6184
# 58:	[0s / 0s],		train_loss: 0.6925,	val_loss: 0.6189
# 59:	[0s / 0s],		train_loss: 0.6725,	val_loss: 0.6386
# 60:	[0s / 0s],		train_loss: 0.7097,	val_loss: 0.6392
# 61:	[0s / 0s],		train_loss: 0.6748,	val_loss: 0.6411
# 62:	[0s / 0s],		train_loss: 0.7175,	val_loss: 0.6577
# 63:	[0s / 0s],		train_loss: 0.7010,	val_loss: 0.6276
# 64:	[0s / 0s],		train_loss: 0.6516,	val_loss: 0.6216
# 65:	[0s / 0s],		train_loss: 0.6695,	val_loss: 0.6274
# 66:	[0s / 0s],		train_loss: 0.6657,	val_loss: 0.6233
# 67:	[0s / 0s],		train_loss: 0.6507,	val_loss: 0.6187
# /Users/simrantanwar/opt/anaconda3/envs/venv/lib/python3.9/site-packages/torchtuples/base.py:669: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.net.load_state_dict(torch.load(path, **kwargs))

# %%
_ = log.plot()

# %% [markdown]
# # Prediction

# %%
surv = model.predict_surv_df(x_test)

# %%
surv.iloc[:, :5].plot(drawstyle='steps-post')
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')

# %%
surv = model.interpolate(10).predict_surv_df(x_test)

# %%
surv.iloc[:, :5].plot(drawstyle='steps-post')
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')

# %% [markdown]
# # Evaluation

# %%
ev = EvalSurv(surv, durations_test, events_test, censor_surv='km')

# %% [markdown]
# # Concordance

# %%
ev.concordance_td('antolini')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 0.8395451674036639

# %% [markdown]
# # beier score

# %%
time_grid = np.linspace(durations_test.min(), durations_test.max(), 100)
ev.brier_score(time_grid).plot()
plt.ylabel('Brier score')
_ = plt.xlabel('Time')

# %%
ev.integrated_brier_score(time_grid)
# Out:
# np.float64(0.1300481115007057)

# %% [markdown]
# # Negatvie binominal log likelihood

# %%
ev.nbll(time_grid).plot()
plt.ylabel('NBLL')
_ = plt.xlabel('Time')

# %%
ev.integrated_nbll(time_grid)
# Out:
# np.float64(0.3960618124552969)
