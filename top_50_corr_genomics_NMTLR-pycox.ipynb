# %% [markdown]
# # NMTLR

# %%
import numpy as np
import matplotlib.pyplot as plt

# For preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper 

import torch # For building the networks 
import torchtuples as tt # Some useful functions

#from pycox.datasets import metabric
from pycox.models import MTLR
from pycox.evaluation import EvalSurv
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from pycox.models.utils import pad_col

# %%
def analyze_file(data):
    print("Dataset:")
    display(data)
    
    # Output the shape of the dataset
    print("\nShape of the dataset (rows, columns):")
    print(data.shape)
    
    # Output the data types of each column
    print("\nData types of each column:")
    print(data.dtypes)
    
    # Output the count of missing values in each column
    print("\nCount of missing values in each column:")
    print(data.isnull().sum())
def get_high_correlation_features(df, target_columns, threshold=0.9):
    """
    Get features with correlation greater than the specified threshold with the target variables.

    Parameters:
    - df (pd.DataFrame): The input DataFrame with features and target variables.
    - target_columns (list of str): List of target variable column names.
    - threshold (float): Correlation threshold to filter features.

    Returns:
    - dict: A dictionary where keys are column names and values are their correlation values.
    """
    high_corr_features = {}

    # Compute correlation matrix
    corr_matrix = df.corr()

    # Iterate over columns in the DataFrame
    for column in df.columns:
        if column not in target_columns:
            # Check correlation with each target variable
            for target in target_columns:
                correlation_value = corr_matrix.loc[column, target]
                if abs(correlation_value) > threshold:
                    high_corr_features[column] = correlation_value
                    break  # No need to check other targets for this feature

    return high_corr_features

# %%
np.random.seed(1234)
_ = torch.manual_seed(123)

# %% [markdown]
# # Dataset

# %%
data = pd.read_csv('/Users/simrantanwar/Desktop/College/DDP/survival_analysis/data/genomics_brain_16_09_24.csv')
analyze_file(data)
# Out:
# Dataset:
#      Unnamed: 0    Patient ID     LASP1    HOXA11    CREBBP       ETV1  \
# 0             0  TCGA-02-0047  8.923858  3.526361  8.244071   8.900549
# 1             1  TCGA-02-0055  8.460199  3.970292  7.816014   7.650645
# 2             2  TCGA-02-2483  9.164296  4.682131  8.572628  10.186973
# 3             3  TCGA-02-2485  9.133675  3.970292  8.474077   9.155250
# 4             4  TCGA-02-2486  8.626765  3.526361  7.090910   6.838405
# ..          ...           ...       ...       ...       ...        ...
# 660        8698  TCGA-WY-A85A  9.093245  1.791759  8.631414  10.231928
# 661        8699  TCGA-WY-A85B  8.977778  2.397895  8.905037  10.492523
# 662        8700  TCGA-WY-A85C  8.820552  6.282267  9.278466   9.983315
# 663        8701  TCGA-WY-A85D  8.793612  0.000000  8.634443   8.751316
# 664        8702  TCGA-WY-A85E  9.264734  6.905753  9.007490  11.213805
#
#          GAS7     CD79B      PAX7       BTK  ...      CUX1   PIERCE2  \
# 0    9.184510  3.555348  2.302585  6.255750  ...  8.282483  4.127134
# 1    7.964156  2.890372  1.609438  6.614726  ...  8.368693  4.276666
# 2    8.340217  2.944439  1.609438  6.146329  ...  8.606302  3.931826
# 3    6.938284  2.564949  1.791759  5.780744  ...  8.629629  4.369448
# 4    8.690642  2.995732  0.693147  7.329750  ...  8.512382  5.793014
# ..        ...       ...       ...       ...  ...       ...       ...
# 660  7.642524  0.693147  2.397895  5.602119  ...  8.810460  3.891820
# 661  7.574558  2.484907  1.386294  6.572283  ...  9.015906  4.234107
# 662  7.007601  1.945910  1.945910  5.730100  ...  9.177714  3.610918
# 663  7.677400  2.197225  0.000000  5.983936  ...  8.861208  3.637586
# 664  8.427925  1.098612  3.178054  5.575949  ...  9.214631  3.828641
#
#        SRGAP2     NCOA4  SSX4     TAF15     MLLT6  DUX4L1   OS  OS.time
# 0    8.053251  9.012621   0.0  8.319474  8.334952     0.0  1.0    448.0
# 1    7.794823  8.727130   0.0  8.235361  7.855157     0.0  1.0     76.0
# 2    8.222554  9.270965   0.0  8.883779  8.491260     0.0  0.0    466.0
# 3    8.235361  8.687779   0.0  9.019301  8.461046     0.0  0.0    470.0
# 4    7.963460  8.760139   0.0  8.525161  8.006034     0.0  1.0    618.0
# ..        ...       ...   ...       ...       ...     ...  ...      ...
# 660  7.765993  8.910586   0.0  8.927977  9.006509     0.0  0.0   1320.0
# 661  7.955074  9.328568   0.0  9.316770  9.229849     0.0  0.0   1393.0
# 662  8.107720  9.145909   0.0  9.151757  9.219696     0.0  0.0   1426.0
# 663  7.914983  8.731498   0.0  9.364005  8.856234     0.0  0.0   1147.0
# 664  8.082402  9.217812   0.0  9.259511  9.265018     0.0  0.0    633.0
#
# [665 rows x 752 columns]
# Shape of the dataset (rows, columns):
# (665, 752)
#
# Data types of each column:
# Unnamed: 0      int64
# Patient ID     object
# LASP1         float64
# HOXA11        float64
# CREBBP        float64
#                ...
# TAF15         float64
# MLLT6         float64
# DUX4L1        float64
# OS            float64
# OS.time       float64
# Length: 752, dtype: object
#
# Count of missing values in each column:
# Unnamed: 0    0
# Patient ID    0
# LASP1         0
# HOXA11        0
# CREBBP        0
#              ..
# TAF15         0
# MLLT6         0
# DUX4L1        0
# OS            0
# OS.time       0
# Length: 752, dtype: int64

# %%
df = data.drop(columns=['Unnamed: 0','Patient ID'], axis=1)
analyze_file(df)
# Out:
# Dataset:
#         LASP1    HOXA11    CREBBP       ETV1      GAS7     CD79B      PAX7  \
# 0    8.923858  3.526361  8.244071   8.900549  9.184510  3.555348  2.302585
# 1    8.460199  3.970292  7.816014   7.650645  7.964156  2.890372  1.609438
# 2    9.164296  4.682131  8.572628  10.186973  8.340217  2.944439  1.609438
# 3    9.133675  3.970292  8.474077   9.155250  6.938284  2.564949  1.791759
# 4    8.626765  3.526361  7.090910   6.838405  8.690642  2.995732  0.693147
# ..        ...       ...       ...        ...       ...       ...       ...
# 660  9.093245  1.791759  8.631414  10.231928  7.642524  0.693147  2.397895
# 661  8.977778  2.397895  8.905037  10.492523  7.574558  2.484907  1.386294
# 662  8.820552  6.282267  9.278466   9.983315  7.007601  1.945910  1.945910
# 663  8.793612  0.000000  8.634443   8.751316  7.677400  2.197225  0.000000
# 664  9.264734  6.905753  9.007490  11.213805  8.427925  1.098612  3.178054
#
#           BTK     BRCA1       WAS  ...      CUX1   PIERCE2    SRGAP2  \
# 0    6.255750  6.257668  7.026427  ...  8.282483  4.127134  8.053251
# 1    6.614726  5.605802  7.315884  ...  8.368693  4.276666  7.794823
# 2    6.146329  6.932448  6.867974  ...  8.606302  3.931826  8.222554
# 3    5.780744  6.970730  6.242223  ...  8.629629  4.369448  8.235361
# 4    7.329750  5.683580  7.600902  ...  8.512382  5.793014  7.963460
# ..        ...       ...       ...  ...       ...       ...       ...
# 660  5.602119  5.849325  6.272877  ...  8.810460  3.891820  7.765993
# 661  6.572283  6.376727  7.059618  ...  9.015906  4.234107  7.955074
# 662  5.730100  6.347389  6.428105  ...  9.177714  3.610918  8.107720
# 663  5.983936  5.796058  6.858565  ...  8.861208  3.637586  7.914983
# 664  5.575949  6.218600  6.347389  ...  9.214631  3.828641  8.082402
#
#         NCOA4  SSX4     TAF15     MLLT6  DUX4L1   OS  OS.time
# 0    9.012621   0.0  8.319474  8.334952     0.0  1.0    448.0
# 1    8.727130   0.0  8.235361  7.855157     0.0  1.0     76.0
# 2    9.270965   0.0  8.883779  8.491260     0.0  0.0    466.0
# 3    8.687779   0.0  9.019301  8.461046     0.0  0.0    470.0
# 4    8.760139   0.0  8.525161  8.006034     0.0  1.0    618.0
# ..        ...   ...       ...       ...     ...  ...      ...
# 660  8.910586   0.0  8.927977  9.006509     0.0  0.0   1320.0
# 661  9.328568   0.0  9.316770  9.229849     0.0  0.0   1393.0
# 662  9.145909   0.0  9.151757  9.219696     0.0  0.0   1426.0
# 663  8.731498   0.0  9.364005  8.856234     0.0  0.0   1147.0
# 664  9.217812   0.0  9.259511  9.265018     0.0  0.0    633.0
#
# [665 rows x 750 columns]
# Shape of the dataset (rows, columns):
# (665, 750)
#
# Data types of each column:
# LASP1      float64
# HOXA11     float64
# CREBBP     float64
# ETV1       float64
# GAS7       float64
#             ...
# TAF15      float64
# MLLT6      float64
# DUX4L1     float64
# OS         float64
# OS.time    float64
# Length: 750, dtype: object
#
# Count of missing values in each column:
# LASP1      0
# HOXA11     0
# CREBBP     0
# ETV1       0
# GAS7       0
#           ..
# TAF15      0
# MLLT6      0
# DUX4L1     0
# OS         0
# OS.time    0
# Length: 750, dtype: int64

# %%
target_columns = ['OS','OS.time']
corr_value = get_high_correlation_features(df, target_columns, threshold=0.3)
#print(corr_value)
print(len(corr_value))
sorted_corr_value = dict(sorted(corr_value.items(), key=lambda item: item[1], reverse=True))
# Out:
# 131

# %%
top_50_genes =list(sorted_corr_value.keys())[:50]


# Assuming 'target' and 'duration' are already identified from the column names
target_columns = ['OS','OS.time']

# Combine the top 20 genea and the additional columns
columns_to_select =  top_50_genes + target_columns

# Create a new DataFrame with these columns
top_50_genes_df = df[columns_to_select]

# %%
# Create a test set by sampling 20% of the training data
df_test = top_50_genes_df.sample(frac=0.2)

# Remove the test set from the original training data
df_train = top_50_genes_df.drop(df_test.index)

# Create a validation set by sampling 20% of the remaining training data
df_val = df_train.sample(frac=0.2)

# Remove the validation set from the remaining training data
df_train = df_train.drop(df_val.index)

# %%
analyze_file(df_train)
# Out:
# Dataset:
#        HOXD11        MSN   IGF2BP2     TMSB4X    HOXC11     FKBP9    HOXC13  \
# 0    3.871201  10.236884  6.167516  11.127586  4.276666  8.697012  2.833213
# 1    3.496508  10.350606  6.946976  11.797405  4.430817  9.072227  4.644391
# 2    2.079442   9.214233  6.539586  11.569457  5.855072  7.635304  5.420535
# 3    4.770685   9.937454  5.278115  11.443211  6.523562  8.772145  6.982863
# 4    2.397895  10.488855  7.297091  12.058431  1.791759  8.614138  1.945910
# ..        ...        ...       ...        ...       ...       ...       ...
# 658  0.000000   9.066470  3.912023  10.912285  0.000000  7.338888  0.000000
# 659  0.000000   7.939872  4.060443  10.650010  1.791759  7.598900  0.000000
# 660  0.000000   9.538708  3.367296   9.935858  0.000000  7.261225  0.000000
# 661  0.000000   8.551208  3.178054  10.644877  0.000000  7.042286  0.000000
# 663  0.000000   7.981733  2.772589  10.751585  0.000000  6.658011  0.000000
#
#        HOXD13     HMGA2    CDKN2C  ...      TFRC   SLC34A2     FANCA  \
# 0    5.703782  4.174387  7.558517  ...  8.512783  6.340359  5.805135
# 1    5.075174  6.177944  7.784889  ...  8.934455  1.098612  5.837730
# 2    6.206576  4.394449  8.771990  ...  8.414496  5.049856  6.858565
# 3    6.860664  3.806662  8.491875  ...  8.814182  4.369448  6.818924
# 4    2.484907  6.018593  7.006695  ...  8.707979  5.318120  4.488636
# ..        ...       ...       ...  ...       ...       ...       ...
# 658  0.000000  1.098612  7.400621  ...  7.509335  1.609438  5.347108
# 659  3.465736  0.693147  6.403574  ...  7.314553  3.555348  6.263398
# 660  0.000000  0.000000  5.505332  ...  7.503290  1.609438  5.176150
# 661  0.000000  0.000000  7.191429  ...  7.434257  3.761200  5.926926
# 663  0.000000  0.000000  6.104793  ...  7.478735  2.197225  4.912655
#
#         SFRP4     CD79B     CHIC2       WT1       CD74   OS  OS.time
# 0    6.504288  3.555348  6.161207  1.098612  11.647133  1.0    448.0
# 1    9.526974  2.890372  7.255591  4.983607  12.126456  1.0     76.0
# 2    6.133398  2.944439  7.116394  2.302585  11.319790  0.0    466.0
# 3    6.754604  2.564949  9.859536  0.693147  11.062521  0.0    470.0
# 4    7.430114  2.995732  6.461468  0.000000  11.924346  1.0    618.0
# ..        ...       ...       ...       ...        ...  ...      ...
# 658  5.407172  3.091042  5.442418  0.000000  11.593602  0.0   1337.0
# 659  4.204693  0.693147  6.393591  2.079442   9.418898  0.0   1213.0
# 660  3.850148  0.693147  5.942799  0.693147   9.986863  0.0   1320.0
# 661  5.231109  2.484907  6.380123  0.000000  10.639646  0.0   1393.0
# 663  7.062192  2.197225  5.869297  4.077537   9.653487  0.0   1147.0
#
# [426 rows x 52 columns]
# Shape of the dataset (rows, columns):
# (426, 52)
#
# Data types of each column:
# HOXD11      float64
# MSN         float64
# IGF2BP2     float64
# TMSB4X      float64
# HOXC11      float64
# FKBP9       float64
# HOXC13      float64
# HOXD13      float64
# HMGA2       float64
# CDKN2C      float64
# STIL        float64
# MACC1       float64
# PAX3        float64
# CHEK2       float64
# SOCS1       float64
# BCL2L12     float64
# COL3A1      float64
# LATS2       float64
# TPM4        float64
# ASPM        float64
# HOXA9       float64
# BCL3        float64
# MYD88       float64
# CASP8       float64
# COL1A1      float64
# FCGR2B      float64
# PDCD1LG2    float64
# BRIP1       float64
# RMI2        float64
# BUB1B       float64
# POLQ        float64
# RUNX1       float64
# APOBEC3B    float64
# TNFRSF14    float64
# FANCD2      float64
# KNL1        float64
# ELF4        float64
# CASP3       float64
# BRCA2       float64
# FADD        float64
# HOXA11      float64
# HK3         float64
# TFRC        float64
# SLC34A2     float64
# FANCA       float64
# SFRP4       float64
# CD79B       float64
# CHIC2       float64
# WT1         float64
# CD74        float64
# OS          float64
# OS.time     float64
# dtype: object
#
# Count of missing values in each column:
# HOXD11      0
# MSN         0
# IGF2BP2     0
# TMSB4X      0
# HOXC11      0
# FKBP9       0
# HOXC13      0
# HOXD13      0
# HMGA2       0
# CDKN2C      0
# STIL        0
# MACC1       0
# PAX3        0
# CHEK2       0
# SOCS1       0
# BCL2L12     0
# COL3A1      0
# LATS2       0
# TPM4        0
# ASPM        0
# HOXA9       0
# BCL3        0
# MYD88       0
# CASP8       0
# COL1A1      0
# FCGR2B      0
# PDCD1LG2    0
# BRIP1       0
# RMI2        0
# BUB1B       0
# POLQ        0
# RUNX1       0
# APOBEC3B    0
# TNFRSF14    0
# FANCD2      0
# KNL1        0
# ELF4        0
# CASP3       0
# BRCA2       0
# FADD        0
# HOXA11      0
# HK3         0
# TFRC        0
# SLC34A2     0
# FANCA       0
# SFRP4       0
# CD79B       0
# CHIC2       0
# WT1         0
# CD74        0
# OS          0
# OS.time     0
# dtype: int64

# %% [markdown]
# # Featrue transform

# %%
columns = top_50_genes_df.columns.tolist()
cols_standardize = columns[:-2]+columns[-1:]
print(cols_standardize)
#cols_leave = ['type', 'gender','Outcome','tumor_status','OS']

standardize = [([col], StandardScaler()) for col in cols_standardize]
#leave = [(col, None) for col in cols_leave]

x_mapper = DataFrameMapper(standardize)
# Out:
# ['HOXD11', 'MSN', 'IGF2BP2', 'TMSB4X', 'HOXC11', 'FKBP9', 'HOXC13', 'HOXD13', 'HMGA2', 'CDKN2C', 'STIL', 'MACC1', 'PAX3', 'CHEK2', 'SOCS1', 'BCL2L12', 'COL3A1', 'LATS2', 'TPM4', 'ASPM', 'HOXA9', 'BCL3', 'MYD88', 'CASP8', 'COL1A1', 'FCGR2B', 'PDCD1LG2', 'BRIP1', 'RMI2', 'BUB1B', 'POLQ', 'RUNX1', 'APOBEC3B', 'TNFRSF14', 'FANCD2', 'KNL1', 'ELF4', 'CASP3', 'BRCA2', 'FADD', 'HOXA11', 'HK3', 'TFRC', 'SLC34A2', 'FANCA', 'SFRP4', 'CD79B', 'CHIC2', 'WT1', 'CD74', 'OS.time']

# %%
x_train = x_mapper.fit_transform(df_train).astype('float32')
x_val = x_mapper.transform(df_val).astype('float32')
x_test = x_mapper.transform(df_test).astype('float32')

# %% [markdown]
# # Label Transforms
# The survival methods require individual label transforms, so we have included a proposed label_transform for each method. In this case label_transform is just a shorthand for the class pycox.preprocessing.label_transforms.LabTransDiscreteTime.
#
# The MTLR is a discrete-time method, meaning it requires discretization of the event times to be applied to continuous-time data. We let num_durations define the size of this (equidistant) discretization grid, meaning our network will have num_durations output nodes.

# %%
num_durations = 10
labtrans = MTLR.label_transform(num_durations)
get_target = lambda gene_expressions_10_df: (gene_expressions_10_df['OS.time'].values, gene_expressions_10_df['OS'].values)
y_train = labtrans.fit_transform(*get_target(df_train))
y_val = labtrans.transform(*get_target(df_val))

train = (x_train, y_train)
val = (x_val, y_val)

# We don't need to transform the test labels
durations_test, events_test = get_target(df_test)

# %%
type(labtrans)
# Out:
# pycox.preprocessing.label_transforms.LabTransDiscreteTime

# %% [markdown]
# # Neural Net
# We make a neural net with torch. For simple network structures, we can use the MLPVanilla provided by torchtuples.\
# The following net is an MLP with two hidden layers (with 32 nodes each), ReLU activations, and num_nodes output nodes. We also have batch normalization and dropout between the layers.

# %%
in_features = x_train.shape[1]
num_nodes = [32, 32]
out_features = labtrans.out_features
batch_norm = True
dropout = 0.4

net = tt.practical.MLPVanilla(in_features, num_nodes, out_features, batch_norm, dropout)

# %% [markdown]
# # Training

# %%
model = MTLR(net, tt.optim.Adam, duration_index=labtrans.cuts)

# %%
batch_size = 32
lr_finder = model.lr_finder(x_train, y_train, batch_size, tolerance=6)
_ = lr_finder.plot()
# Out:
# /Users/simrantanwar/opt/anaconda3/envs/venv/lib/python3.9/site-packages/torchtuples/base.py:669: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.net.load_state_dict(torch.load(path, **kwargs))

# %%
lr_finder.get_best_lr()
# Out:
# np.float64(0.0001)

# %%
model.optimizer.set_lr(0.0001)

# %%
epochs = 200
callbacks = [tt.callbacks.EarlyStopping()]
log = model.fit(x_train, y_train, batch_size, epochs, callbacks, val_data=val)
# Out:
# 0:	[0s / 0s],		train_loss: 1.2956,	val_loss: 0.9326
# 1:	[0s / 0s],		train_loss: 1.3171,	val_loss: 0.9081
# 2:	[0s / 0s],		train_loss: 1.2225,	val_loss: 0.8900
# 3:	[0s / 0s],		train_loss: 1.2153,	val_loss: 0.8774
# 4:	[0s / 0s],		train_loss: 1.1625,	val_loss: 0.8678
# 5:	[0s / 0s],		train_loss: 1.1596,	val_loss: 0.8591
# 6:	[0s / 0s],		train_loss: 1.1639,	val_loss: 0.8442
# 7:	[0s / 0s],		train_loss: 1.1602,	val_loss: 0.8343
# 8:	[0s / 0s],		train_loss: 1.1579,	val_loss: 0.8268
# 9:	[0s / 0s],		train_loss: 1.1705,	val_loss: 0.8191
# 10:	[0s / 0s],		train_loss: 1.0972,	val_loss: 0.8063
# 11:	[0s / 0s],		train_loss: 1.1389,	val_loss: 0.8071
# 12:	[0s / 0s],		train_loss: 1.0398,	val_loss: 0.8009
# 13:	[0s / 0s],		train_loss: 1.0576,	val_loss: 0.7870
# 14:	[0s / 0s],		train_loss: 1.0050,	val_loss: 0.7843
# 15:	[0s / 0s],		train_loss: 0.9727,	val_loss: 0.7814
# 16:	[0s / 0s],		train_loss: 1.0393,	val_loss: 0.7769
# 17:	[0s / 0s],		train_loss: 0.9496,	val_loss: 0.7742
# 18:	[0s / 0s],		train_loss: 1.0401,	val_loss: 0.7723
# 19:	[0s / 0s],		train_loss: 0.9906,	val_loss: 0.7765
# 20:	[0s / 0s],		train_loss: 0.9595,	val_loss: 0.7740
# 21:	[0s / 0s],		train_loss: 0.9649,	val_loss: 0.7539
# 22:	[0s / 0s],		train_loss: 0.9371,	val_loss: 0.7556
# 23:	[0s / 0s],		train_loss: 0.9219,	val_loss: 0.7485
# 24:	[0s / 0s],		train_loss: 0.9325,	val_loss: 0.7372
# 25:	[0s / 0s],		train_loss: 0.9163,	val_loss: 0.7369
# 26:	[0s / 0s],		train_loss: 0.9474,	val_loss: 0.7303
# 27:	[0s / 0s],		train_loss: 0.8818,	val_loss: 0.7380
# 28:	[0s / 0s],		train_loss: 0.9294,	val_loss: 0.7421
# 29:	[0s / 0s],		train_loss: 0.8682,	val_loss: 0.7242
# 30:	[0s / 0s],		train_loss: 0.9331,	val_loss: 0.7357
# 31:	[0s / 0s],		train_loss: 0.8749,	val_loss: 0.7168
# 32:	[0s / 0s],		train_loss: 0.8424,	val_loss: 0.7199
# 33:	[0s / 0s],		train_loss: 0.9187,	val_loss: 0.7018
# 34:	[0s / 0s],		train_loss: 0.8481,	val_loss: 0.7056
# 35:	[0s / 0s],		train_loss: 0.8535,	val_loss: 0.7120
# 36:	[0s / 0s],		train_loss: 0.8379,	val_loss: 0.7013
# 37:	[0s / 0s],		train_loss: 0.8167,	val_loss: 0.7081
# 38:	[0s / 0s],		train_loss: 0.8480,	val_loss: 0.7029
# 39:	[0s / 0s],		train_loss: 0.8815,	val_loss: 0.7031
# 40:	[0s / 0s],		train_loss: 0.8154,	val_loss: 0.6954
# 41:	[0s / 0s],		train_loss: 0.8183,	val_loss: 0.6767
# 42:	[0s / 0s],		train_loss: 0.8286,	val_loss: 0.6887
# 43:	[0s / 0s],		train_loss: 0.8356,	val_loss: 0.6833
# 44:	[0s / 0s],		train_loss: 0.7947,	val_loss: 0.6906
# 45:	[0s / 0s],		train_loss: 0.8159,	val_loss: 0.6818
# 46:	[0s / 0s],		train_loss: 0.7658,	val_loss: 0.6748
# 47:	[0s / 0s],		train_loss: 0.7543,	val_loss: 0.6793
# 48:	[0s / 0s],		train_loss: 0.7719,	val_loss: 0.6789
# 49:	[0s / 0s],		train_loss: 0.7552,	val_loss: 0.6666
# 50:	[0s / 0s],		train_loss: 0.8477,	val_loss: 0.6694
# 51:	[0s / 0s],		train_loss: 0.7680,	val_loss: 0.6729
# 52:	[0s / 0s],		train_loss: 0.7611,	val_loss: 0.6644
# 53:	[0s / 0s],		train_loss: 0.7930,	val_loss: 0.6533
# 54:	[0s / 0s],		train_loss: 0.7570,	val_loss: 0.6545
# 55:	[0s / 0s],		train_loss: 0.7873,	val_loss: 0.6430
# 56:	[0s / 0s],		train_loss: 0.7427,	val_loss: 0.6601
# 57:	[0s / 0s],		train_loss: 0.7227,	val_loss: 0.6468
# 58:	[0s / 0s],		train_loss: 0.7614,	val_loss: 0.6496
# 59:	[0s / 0s],		train_loss: 0.7513,	val_loss: 0.6339
# 60:	[0s / 0s],		train_loss: 0.8253,	val_loss: 0.6524
# 61:	[0s / 0s],		train_loss: 0.7030,	val_loss: 0.6577
# 62:	[0s / 0s],		train_loss: 0.7330,	val_loss: 0.6426
# 63:	[0s / 0s],		train_loss: 0.7367,	val_loss: 0.6353
# 64:	[0s / 0s],		train_loss: 0.7482,	val_loss: 0.6416
# 65:	[0s / 0s],		train_loss: 0.7023,	val_loss: 0.6162
# 66:	[0s / 0s],		train_loss: 0.6890,	val_loss: 0.6339
# 67:	[0s / 0s],		train_loss: 0.6932,	val_loss: 0.6215
# 68:	[0s / 0s],		train_loss: 0.6602,	val_loss: 0.6147
# 69:	[0s / 0s],		train_loss: 0.6800,	val_loss: 0.6327
# 70:	[0s / 0s],		train_loss: 0.7402,	val_loss: 0.6281
# 71:	[0s / 0s],		train_loss: 0.7304,	val_loss: 0.6335
# 72:	[0s / 0s],		train_loss: 0.7550,	val_loss: 0.6287
# 73:	[0s / 0s],		train_loss: 0.7224,	val_loss: 0.6414
# 74:	[0s / 0s],		train_loss: 0.6886,	val_loss: 0.6139
# 75:	[0s / 0s],		train_loss: 0.7167,	val_loss: 0.6064
# 76:	[0s / 0s],		train_loss: 0.6631,	val_loss: 0.6114
# 77:	[0s / 0s],		train_loss: 0.6990,	val_loss: 0.6138
# 78:	[0s / 0s],		train_loss: 0.6977,	val_loss: 0.6181
# 79:	[0s / 0s],		train_loss: 0.6693,	val_loss: 0.6089
# 80:	[0s / 0s],		train_loss: 0.6568,	val_loss: 0.6184
# 81:	[0s / 0s],		train_loss: 0.6845,	val_loss: 0.5995
# 82:	[0s / 0s],		train_loss: 0.6741,	val_loss: 0.5929
# 83:	[0s / 0s],		train_loss: 0.6567,	val_loss: 0.6069
# 84:	[0s / 0s],		train_loss: 0.6552,	val_loss: 0.6050
# 85:	[0s / 0s],		train_loss: 0.6720,	val_loss: 0.5938
# 86:	[0s / 0s],		train_loss: 0.6758,	val_loss: 0.6051
# 87:	[0s / 0s],		train_loss: 0.6734,	val_loss: 0.5850
# 88:	[0s / 0s],		train_loss: 0.6391,	val_loss: 0.5842
# 89:	[0s / 0s],		train_loss: 0.6732,	val_loss: 0.5853
# 90:	[0s / 0s],		train_loss: 0.6460,	val_loss: 0.5885
# 91:	[0s / 0s],		train_loss: 0.6397,	val_loss: 0.5906
# 92:	[0s / 0s],		train_loss: 0.6321,	val_loss: 0.5835
# 93:	[0s / 1s],		train_loss: 0.6305,	val_loss: 0.5788
# 94:	[0s / 1s],		train_loss: 0.6359,	val_loss: 0.5706
# 95:	[0s / 1s],		train_loss: 0.6880,	val_loss: 0.5841
# 96:	[0s / 1s],		train_loss: 0.6527,	val_loss: 0.5841
# 97:	[0s / 1s],		train_loss: 0.6065,	val_loss: 0.5756
# 98:	[0s / 1s],		train_loss: 0.6249,	val_loss: 0.5800
# 99:	[0s / 1s],		train_loss: 0.6315,	val_loss: 0.5888
# 100:	[0s / 1s],		train_loss: 0.6696,	val_loss: 0.5965
# 101:	[0s / 1s],		train_loss: 0.6534,	val_loss: 0.5702
# 102:	[0s / 1s],		train_loss: 0.6018,	val_loss: 0.5832
# 103:	[0s / 1s],		train_loss: 0.6324,	val_loss: 0.5600
# 104:	[0s / 1s],		train_loss: 0.6166,	val_loss: 0.5749
# 105:	[0s / 1s],		train_loss: 0.6194,	val_loss: 0.5796
# 106:	[0s / 1s],		train_loss: 0.6607,	val_loss: 0.5624
# 107:	[0s / 1s],		train_loss: 0.6103,	val_loss: 0.5633
# 108:	[0s / 1s],		train_loss: 0.6081,	val_loss: 0.5697
# 109:	[0s / 1s],		train_loss: 0.6083,	val_loss: 0.5674
# 110:	[0s / 1s],		train_loss: 0.6027,	val_loss: 0.5649
# 111:	[0s / 1s],		train_loss: 0.6105,	val_loss: 0.5717
# 112:	[0s / 1s],		train_loss: 0.6211,	val_loss: 0.5693
# 113:	[0s / 1s],		train_loss: 0.5891,	val_loss: 0.5574
# 114:	[0s / 1s],		train_loss: 0.5913,	val_loss: 0.5504
# 115:	[0s / 1s],		train_loss: 0.6133,	val_loss: 0.5617
# 116:	[0s / 1s],		train_loss: 0.5871,	val_loss: 0.5622
# 117:	[0s / 1s],		train_loss: 0.5995,	val_loss: 0.5637
# 118:	[0s / 1s],		train_loss: 0.6310,	val_loss: 0.5763
# 119:	[0s / 1s],		train_loss: 0.5933,	val_loss: 0.5489
# 120:	[0s / 1s],		train_loss: 0.5856,	val_loss: 0.5478
# 121:	[0s / 1s],		train_loss: 0.5721,	val_loss: 0.5602
# 122:	[0s / 1s],		train_loss: 0.5725,	val_loss: 0.5476
# 123:	[0s / 1s],		train_loss: 0.5505,	val_loss: 0.5553
# 124:	[0s / 1s],		train_loss: 0.5481,	val_loss: 0.5447
# 125:	[0s / 1s],		train_loss: 0.5505,	val_loss: 0.5509
# 126:	[0s / 1s],		train_loss: 0.5384,	val_loss: 0.5500
# 127:	[0s / 1s],		train_loss: 0.5689,	val_loss: 0.5488
# 128:	[0s / 1s],		train_loss: 0.5844,	val_loss: 0.5340
# 129:	[0s / 1s],		train_loss: 0.5542,	val_loss: 0.5441
# 130:	[0s / 1s],		train_loss: 0.6185,	val_loss: 0.5348
# 131:	[0s / 1s],		train_loss: 0.5721,	val_loss: 0.5403
# 132:	[0s / 1s],		train_loss: 0.5595,	val_loss: 0.5350
# 133:	[0s / 1s],		train_loss: 0.5694,	val_loss: 0.5339
# 134:	[0s / 1s],		train_loss: 0.5433,	val_loss: 0.5412
# 135:	[0s / 1s],		train_loss: 0.5964,	val_loss: 0.5312
# 136:	[0s / 1s],		train_loss: 0.5360,	val_loss: 0.5338
# 137:	[0s / 1s],		train_loss: 0.5565,	val_loss: 0.5344
# 138:	[0s / 1s],		train_loss: 0.5419,	val_loss: 0.5322
# 139:	[0s / 1s],		train_loss: 0.5431,	val_loss: 0.5402
# 140:	[0s / 1s],		train_loss: 0.5649,	val_loss: 0.5306
# 141:	[0s / 1s],		train_loss: 0.5643,	val_loss: 0.5396
# 142:	[0s / 1s],		train_loss: 0.5174,	val_loss: 0.5397
# 143:	[0s / 1s],		train_loss: 0.5819,	val_loss: 0.5452
# 144:	[0s / 1s],		train_loss: 0.5395,	val_loss: 0.5321
# 145:	[0s / 1s],		train_loss: 0.5574,	val_loss: 0.5268
# 146:	[0s / 1s],		train_loss: 0.5853,	val_loss: 0.5159
# 147:	[0s / 1s],		train_loss: 0.5690,	val_loss: 0.5198
# 148:	[0s / 1s],		train_loss: 0.5731,	val_loss: 0.5121
# 149:	[0s / 1s],		train_loss: 0.5881,	val_loss: 0.5370
# 150:	[0s / 1s],		train_loss: 0.5498,	val_loss: 0.5242
# 151:	[0s / 1s],		train_loss: 0.5325,	val_loss: 0.5264
# 152:	[0s / 1s],		train_loss: 0.5378,	val_loss: 0.5174
# 153:	[0s / 1s],		train_loss: 0.5522,	val_loss: 0.5236
# 154:	[0s / 1s],		train_loss: 0.5450,	val_loss: 0.5020
# 155:	[0s / 1s],		train_loss: 0.5104,	val_loss: 0.5243
# 156:	[0s / 1s],		train_loss: 0.5260,	val_loss: 0.5102
# 157:	[0s / 1s],		train_loss: 0.4863,	val_loss: 0.5113
# 158:	[0s / 1s],		train_loss: 0.5460,	val_loss: 0.5090
# 159:	[0s / 1s],		train_loss: 0.5275,	val_loss: 0.5189
# 160:	[0s / 1s],		train_loss: 0.5161,	val_loss: 0.5096
# 161:	[0s / 1s],		train_loss: 0.5146,	val_loss: 0.5179
# 162:	[0s / 1s],		train_loss: 0.5173,	val_loss: 0.4909
# 163:	[0s / 1s],		train_loss: 0.4923,	val_loss: 0.5097
# 164:	[0s / 1s],		train_loss: 0.5656,	val_loss: 0.5084
# 165:	[0s / 1s],		train_loss: 0.5590,	val_loss: 0.5029
# 166:	[0s / 1s],		train_loss: 0.5162,	val_loss: 0.5014
# 167:	[0s / 1s],		train_loss: 0.4908,	val_loss: 0.4910
# 168:	[0s / 1s],		train_loss: 0.5198,	val_loss: 0.5151
# 169:	[0s / 1s],		train_loss: 0.5320,	val_loss: 0.5175
# 170:	[0s / 1s],		train_loss: 0.5194,	val_loss: 0.5104
# 171:	[0s / 1s],		train_loss: 0.5105,	val_loss: 0.5044
# 172:	[0s / 1s],		train_loss: 0.4757,	val_loss: 0.5089
# /Users/simrantanwar/opt/anaconda3/envs/venv/lib/python3.9/site-packages/torchtuples/base.py:669: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.net.load_state_dict(torch.load(path, **kwargs))

# %%
_ = log.plot()

# %% [markdown]
# # Prediction

# %%
surv = model.predict_surv_df(x_test)

# %%
surv.iloc[:, :5].plot(drawstyle='steps-post')
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')

# %%
surv = model.interpolate(10).predict_surv_df(x_test)

# %%
surv.iloc[:, :5].plot(drawstyle='steps-post')
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')

# %% [markdown]
# # Evaluation

# %%
ev = EvalSurv(surv, durations_test, events_test, censor_surv='km')

# %% [markdown]
# # Concordance

# %%
ev.concordance_td('antolini')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 0.8019583070120025

# %% [markdown]
# # beier score

# %%
time_grid = np.linspace(durations_test.min(), durations_test.max(), 100)
ev.brier_score(time_grid).plot()
plt.ylabel('Brier score')
_ = plt.xlabel('Time')

# %%
ev.integrated_brier_score(time_grid)
# Out:
# np.float64(0.10884457768524954)

# %% [markdown]
# # Negatvie binominal log likelihood

# %%
ev.nbll(time_grid).plot()
plt.ylabel('NBLL')
_ = plt.xlabel('Time')

# %%
ev.integrated_nbll(time_grid)
# Out:
# np.float64(0.35071700148019713)
